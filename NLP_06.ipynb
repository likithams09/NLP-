# %% [markdown]
# <a href="https://colab.research.google.com/github/likithams09/NLP-/blob/main/NLP_06.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import spacy

nlp = spacy.load("en_core_web_sm")
print("spaCy model loaded successfully!")
# Out:
# spaCy model loaded successfully!

# %%
text = "Ravi is studying Artificial Intelligence at VTU University in Karnataka."

# %%
doc = nlp(text)

# %%
print("Tokenization:")
for token in doc:
    print(token.text)
# Out:
# Tokenization:
# Ravi
# is
# studying
# Artificial
# Intelligence
# at
# VTU
# University
# in
# Karnataka
# .

# %%
print("\nLemmatization:")
for token in doc:
    print(token.text, "→", token.lemma_)
# Out:
# Lemmatization:
# Ravi → ravi
# is → be
# studying → study
# Artificial → Artificial
# Intelligence → Intelligence
# at → at
# VTU → VTU
# University → University
# in → in
# Karnataka → Karnataka
# . → .

# %%
print("\nPOS Tagging:")
for token in doc:
    print(token.text, "→", token.pos_)
# Out:
# POS Tagging:
# Ravi → NOUN
# is → AUX
# studying → VERB
# Artificial → PROPN
# Intelligence → PROPN
# at → ADP
# VTU → PROPN
# University → PROPN
# in → ADP
# Karnataka → PROPN
# . → PUNCT

# %%
print("\nNamed Entity Recognition:")
for ent in doc.ents:
    print(ent.text, "→", ent.label_)
# Out:
# Named Entity Recognition:
# Artificial Intelligence → ORG
# VTU University → ORG
# Karnataka → GPE

# %%
print("\nStop Word Removal:")
filtered_tokens = [token.text for token in doc if not token.is_stop]
print(filtered_tokens)
# Out:
# Stop Word Removal:
# ['Ravi', 'studying', 'Artificial', 'Intelligence', 'VTU', 'University', 'Karnataka', '.']
